# %%
import arepo
import h5py as h5
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
import matplotlib as mpl

from numba import njit

from joblib import Parallel, delayed

import agama
agama.setUnits(mass=1E10, length=1, velocity=1)

from scipy.interpolate import interp1d

# %%
basepath = '/n/holylfs05/LABS/hernquist_lab/Users/abeane/GSEgas/'

# %%
name = 'GSE6_Seq2_R96_eta0.2-lvl4-rng_-80_80_-80_80_BoxCenter_nres512'
lvl = 'lvl4'
snap = 400

frame = h5.File(basepath + 'anlys/movie/frames/' + name + '/frame' + str(snap).zfill(3) + '.h5', mode='r')

plt.imshow(frame['Hxy_g'][:].T, norm=mpl.colors.LogNorm(vmin=1E-7, vmax=1E-4), origin='lower')
