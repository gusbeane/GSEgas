# %%
import h5py as h5
import arepo
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.interpolate import interp1d

# %%
basepath = '/n/holylfs05/LABS/hernquist_lab/Users/abeane/GSEgas/'

# %%
sfr = {}
sfr['GSE4iso'] = np.genfromtxt(basepath + 'runs/GSE4iso/lvl5/output/sfr.txt')
sfr['GSE4iso_ns'] = np.genfromtxt(basepath + 'runs/GSE4iso/lvl5-newsoft/output/sfr.txt')

# %%
plt.plot(sfr['GSE4iso'][:,0], sfr['GSE4iso'][:,2], label='GSE4iso')
plt.plot(sfr['GSE4iso_ns'][:,0], sfr['GSE4iso_ns'][:,2], label='GSE4iso (new soft)')

plt.legend(frameon=False)

plt.xlim(0, 5)
plt.xlabel('T [Gyr]')
plt.ylabel('SFR [Msun/yr]')

plt.ylim(0, 1)
# plt.xlim(0, 3)
# Out:
# (0.0, 1.0)
