# %%
import numpy as np
import struct
import matplotlib.pyplot as plt

# %%
part = np.genfromtxt('particles.txt')

# %%
plt.hist(part[:,2], bins=100)
print(0)
# Out:
# 0

# %%
plt.hist(part[:,0], bins=100)
print(0)
# Out:
# 0

# %%
plt.hist(part[:,1], bins=100)
print(0)
# Out:
# 0

# %%
R = np.linalg.norm(part[:,:2], axis=1)
plt.hist(R, bins=100)
print(0)
# Out:
# 0

# %%
np.nanmin(R)
# Out:
# 0.04802327161908068
